# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# CelebA Face Generation GAN\n",
    "\n",
    "## Training Notebook\n",
    "\n",
    "This notebook demonstrates the training process for the CelebA GAN.\n",
    "\n",
    "**Prerequisites:**\n",
    "1. Download CelebA dataset\n",
    "2. Update path in scripts/train_celeba.py\n",
    "3. Install dependencies: `pip install -r requirements.txt`"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Setup\n",
    "import os\n",
    "os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'\n",
    "\n",
    "import torch\n",
    "import matplotlib.pyplot as plt\n",
    "import numpy as np\n",
    "from PIL import Image\n",
    "\n",
    "print(f\"PyTorch version: {torch.__version__}\")\n",
    "print(f\"CUDA available: {torch.cuda.is_available()}\")"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Run Training\n",
    "\n",
    "The main training script is in `scripts/train_celeba.py`\n",
    "\n",
    "Run this cell to start training (will take several hours):"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Run training (commented out - uncomment to run)\n",
    "# !python scripts/train_celeba.py"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## View Generated Samples\n",
    "\n",
    "After training, view the generated samples:"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "def show_generated_samples():\n",
    "    \"\"\"Display generated samples\"\"\"\n",
    "    import glob\n",
    "    \n",
    "    # Get latest generated file\n",
    "    sample_files = glob.glob(\"generated_celeba/*.png\")\n",
    "    if not sample_files:\n",
    "        print(\"No generated samples found. Run training first.\")\n",
    "        return\n",
    "    \n",
    "    latest_file = sorted(sample_files)[-1]\n",
    "    \n",
    "    # Display\n",
    "    img = Image.open(latest_file)\n",
    "    plt.figure(figsize=(10, 10))\n",
    "    plt.imshow(img)\n",
    "    plt.axis('off')\n",
    "    plt.title(f\"Generated Faces: {os.path.basename(latest_file)}\")\n",
    "    plt.show()\n",
    "\n",
    "show_generated_samples()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Training Progress\n",
    "\n",
    "Check training metrics:"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "def plot_training_progress():\n",
    "    \"\"\"Plot training metrics if available\"\"\"\n",
    "    import glob\n",
    "    \n",
    "    metrics_file = \"celeba_training_metrics.png\"\n",
    "    \n",
    "    if os.path.exists(metrics_file):\n",
    "        img = Image.open(metrics_file)\n",
    "        plt.figure(figsize=(12, 6))\n",
    "        plt.imshow(img)\n",
    "        plt.axis('off')\n",
    "        plt.title(\"Training Metrics\")\n",
    "        plt.show()\n",
    "    else:\n",
    "        print(\"Training metrics not found. Run training first.\")\n",
    "\n",
    "plot_training_progress()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Notes\n",
    "\n",
    "- Training takes ~60 epochs\n",
    "- Each epoch processes ~200K images\n",
    "- Generated samples saved to `generated_celeba/`\n",
    "- Model checkpoints saved as `.pth` files\n",
    "- After training, run transfer learning: `python scripts/train_transfer.py`"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.8.0"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
